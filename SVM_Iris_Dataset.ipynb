# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import the dataset using Seaborn library
iris=pd.read_csv('C:/Users/PC/OneDrive/Desktop/AL and ML/Final/LAB/Dataset/Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris_new = iris.drop("Id", axis='columns')

# %%
iris_new.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_new.shape
# Out:
# (150, 5)

# %%
# Creating a pairplot to visualize the similarities and especially difference between the species
sns.pairplot(data=iris_new, hue='Species', palette='Set2')

# %%
from sklearn.model_selection import train_test_split

# %%
x=iris_new.iloc[:,:-1]
y=iris_new.iloc[:,4]
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)

# %% [markdown]
# # Model Evaluation

# %%
# Importing the classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[16  0  0]
#  [ 0 12  0]
#  [ 0  0 17]]

# %%
print(classification_report(y_test, pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        12
#  Iris-virginica       1.00      1.00      1.00        17
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
